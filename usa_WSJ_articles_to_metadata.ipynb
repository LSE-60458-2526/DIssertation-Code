# %%
from docx import Document
import pandas as pd
import os

folder = "/Users/yurujia/Desktop/Dissertation Data/USA/WSJ 1-389"

data = []

files = os.listdir(folder)

docx_files = [
    f for f in files
    if f.lower().endswith(".docx") and not f.startswith("~$")
]

print("Found docx files:", len(docx_files))
print(docx_files[:10])

for file in docx_files:
    path = os.path.join(folder, file)

    doc = Document(path)

    paragraphs = []
    for p in doc.paragraphs:
        text = p.text.strip()
        if text:
            paragraphs.append(text)

    full_text = "\n".join(paragraphs)

    title = paragraphs[0] if len(paragraphs) > 0 else None
    date = paragraphs[1] if len(paragraphs) > 1 else None
    source = paragraphs[2] if len(paragraphs) > 2 else None

    data.append({
        "file": file,
        "title": title,
        "date": date,
        "source": source,
        "content": full_text
    })

df = pd.DataFrame(data)

print("Final dataframe shape:", df.shape)
print(df.head())

output_path = os.path.join(folder, "lexis_structured_WSJ_1-389.xlsx")
df.to_excel(output_path, index=False)

print("Saved to:", output_path)
# Out:
# Found docx files: 390
# ['GM MOVES AHEAD AFTER STRIKE, FOCUSING ON COST CUTS, EVS.DOCX', 'CHINA’S TECH GIANTS TAKE TO THE ROAD.DOCX', 'AUTO MAKERS CAN SURVIVE SELF-DRIVING CAR.DOCX', "UBER ADAPTS TO COVID AND 'LABORISM'.DOCX", 'LYFT SELLS SELF-DRIVE DIVISION TO TOYOTA SUBSIDIARY.DOCX', 'WHY WE FIND SELF-DRIVING CARS SO SCARY.DOCX', 'SELF-DRIVE CARS PLANNED IN NEW YORK.DOCX', 'UBER CAR’S FAILURE TO BRAKE PUTS FOCUS ON SENSOR.DOCX', 'GM ’S CRUISE UNIT RECALLS SOFTWARE IN SOME ROBOTAXIS.DOCX', 'WAYMO DRIVERLESS CARS TO ENTER STREETS OF SAN FRANCISCO.DOCX']
# Final dataframe shape: (390, 5)
#                                                 file  \
# 0  GM MOVES AHEAD AFTER STRIKE, FOCUSING ON COST ...
# 1          CHINA’S TECH GIANTS TAKE TO THE ROAD.DOCX
# 2      AUTO MAKERS CAN SURVIVE SELF-DRIVING CAR.DOCX
# 3           UBER ADAPTS TO COVID AND 'LABORISM'.DOCX
# 4  LYFT SELLS SELF-DRIVE DIVISION TO TOYOTA SUBSI...
#
#                                                title  \
# 0  GM MOVES AHEAD AFTER STRIKE, FOCUSING ON COST ...
# 1               CHINA’S TECH GIANTS TAKE TO THE ROAD
# 2           AUTO MAKERS CAN SURVIVE SELF-DRIVING CAR
# 3                UBER ADAPTS TO COVID AND 'LABORISM'
# 4  LYFT SELLS SELF-DRIVE DIVISION TO TOYOTA SUBSI...
#
#                             date                      source  \
# 0  Wall Street Journal Abstracts  December 14, 2023 Thursday
# 1  Wall Street Journal Abstracts       March 19, 2018 Monday
# 2  Wall Street Journal Abstracts    January 10, 2017 Tuesday
# 3  Wall Street Journal Abstracts    October 3, 2020 Saturday
# 4  Wall Street Journal Abstracts      April 27, 2021 Tuesday
#
#                                              content
# 0  GM MOVES AHEAD AFTER STRIKE, FOCUSING ON COST ...
# 1  CHINA’S TECH GIANTS TAKE TO THE ROAD\nWall Str...
# 2  AUTO MAKERS CAN SURVIVE SELF-DRIVING CAR\nWall...
# 3  UBER ADAPTS TO COVID AND 'LABORISM'\nWall Stre...
# 4  LYFT SELLS SELF-DRIVE DIVISION TO TOYOTA SUBSI...
# Saved to: /Users/yurujia/Desktop/Dissertation Data/USA/WSJ 1-389/lexis_structured_WSJ_1-389.xlsx
